# %% [markdown]
# # Detective comix character statz

# %%
# 3rd party imports
import polars as pl
import datetime as dt

# %%
# df = pl.read_csv("../dta/detective.csv")
# df = df.filter(pl.col("Height") != -99).filter(pl.col("Weight") != -99)
# df.write_csv("dc_sanitized_w_h.csv")
# df

# %%
df = pl.read_csv("../dta/dc_sanitized_w_h.csv")



result = df.select(
    pl.col(["Name", "Weight"]),
    (pl.col("Weight") / (pl.col("Height")/100) ** 2).alias("BMI"),
)
result
# Out:
# shape: (131, 3)
# ┌──────────────┬────────┬───────────┐
# │ Name         ┆ Weight ┆ BMI       │
# │ ---          ┆ ---    ┆ ---       │
# │ str          ┆ i64    ┆ f64       │
# ╞══════════════╪════════╪═══════════╡
# │ Adam Strange ┆ 88     ┆ 25.712199 │
# │ Aqualad      ┆ 106    ┆ 33.455372 │
# │ Aquaman      ┆ 146    ┆ 42.658875 │
# │ Atlas        ┆ 126    ┆ 32.139578 │
# │ Atom         ┆ 68     ┆ 21.461937 │
# │ …            ┆ …      ┆ …         │
# │ Warp         ┆ 67     ┆ 22.386314 │
# │ Wonder Girl  ┆ 51     ┆ 18.732782 │
# │ Wonder Woman ┆ 74     ┆ 22.096808 │
# │ Zatanna      ┆ 57     ┆ 19.723183 │
# │ Zoom         ┆ 81     ┆ 23.66691  │
# └──────────────┴────────┴───────────┘

# %%
df.filter(pl.col("Weight") == df["Weight"].max())
# Out:
# shape: (1, 11)
# ┌─────┬──────────┬───────────┬────────┬───┬───────────┬───────────┬────────┬────────┐
# │ ID  ┆ Name     ┆ Alignment ┆ Gender ┆ … ┆ Publisher ┆ SkinColor ┆ Height ┆ Weight │
# │ --- ┆ ---      ┆ ---       ┆ ---    ┆   ┆ ---       ┆ ---       ┆ ---    ┆ ---    │
# │ i64 ┆ str      ┆ str       ┆ str    ┆   ┆ str       ┆ str       ┆ i64    ┆ i64    │
# ╞═════╪══════════╪═══════════╪════════╪═══╪═══════════╪═══════════╪════════╪════════╡
# │ 203 ┆ Darkseid ┆ bad       ┆ Male   ┆ … ┆ DC Comics ┆ grey      ┆ 267    ┆ 817    │
# └─────┴──────────┴───────────┴────────┴───┴───────────┴───────────┴────────┴────────┘

# %%
df.filter(pl.col("Weight") == df["Weight"].min())
# Out:
# shape: (1, 11)
# ┌─────┬────────┬───────────┬────────┬───┬───────────┬───────────┬────────┬────────┐
# │ ID  ┆ Name   ┆ Alignment ┆ Gender ┆ … ┆ Publisher ┆ SkinColor ┆ Height ┆ Weight │
# │ --- ┆ ---    ┆ ---       ┆ ---    ┆   ┆ ---       ┆ ---       ┆ ---    ┆ ---    │
# │ i64 ┆ str    ┆ str       ┆ str    ┆   ┆ str       ┆ str       ┆ i64    ┆ i64    │
# ╞═════╪════════╪═══════════╪════════╪═══╪═══════════╪═══════════╪════════╪════════╡
# │ 396 ┆ Krypto ┆ good      ┆ Male   ┆ … ┆ DC Comics ┆ -         ┆ 64     ┆ 18     │
# └─────┴────────┴───────────┴────────┴───┴───────────┴───────────┴────────┴────────┘

# %%
df.filter(pl.col("Height") == df["Height"].max())
# Out:
# shape: (1, 11)
# ┌─────┬────────────────┬───────────┬────────┬───┬───────────┬───────────┬────────┬────────┐
# │ ID  ┆ Name           ┆ Alignment ┆ Gender ┆ … ┆ Publisher ┆ SkinColor ┆ Height ┆ Weight │
# │ --- ┆ ---            ┆ ---       ┆ ---    ┆   ┆ ---       ┆ ---       ┆ ---    ┆ ---    │
# │ i64 ┆ str            ┆ str       ┆ str    ┆   ┆ str       ┆ str       ┆ i64    ┆ i64    │
# ╞═════╪════════════════╪═══════════╪════════╪═══╪═══════════╪═══════════╪════════╪════════╡
# │ 611 ┆ Solomon Grundy ┆ bad       ┆ Male   ┆ … ┆ DC Comics ┆ -         ┆ 279    ┆ 437    │
# └─────┴────────────────┴───────────┴────────┴───┴───────────┴───────────┴────────┴────────┘

# %%
df.filter(pl.col("Height") == df["Height"].min())
# Out:
# shape: (1, 11)
# ┌─────┬────────┬───────────┬────────┬───┬───────────┬───────────┬────────┬────────┐
# │ ID  ┆ Name   ┆ Alignment ┆ Gender ┆ … ┆ Publisher ┆ SkinColor ┆ Height ┆ Weight │
# │ --- ┆ ---    ┆ ---       ┆ ---    ┆   ┆ ---       ┆ ---       ┆ ---    ┆ ---    │
# │ i64 ┆ str    ┆ str       ┆ str    ┆   ┆ str       ┆ str       ┆ i64    ┆ i64    │
# ╞═════╪════════╪═══════════╪════════╪═══╪═══════════╪═══════════╪════════╪════════╡
# │ 396 ┆ Krypto ┆ good      ┆ Male   ┆ … ┆ DC Comics ┆ -         ┆ 64     ┆ 18     │
# └─────┴────────┴───────────┴────────┴───┴───────────┴───────────┴────────┴────────┘

# %%
import matplotlib.pyplot as plt

# %%
data = df.group_by("Alignment").len() # #value_counts()
color = ["red","blue", "yellow", "green"]

plt.subplots(figsize =(10,10))
plt.pie(data["len"],labels=data["Alignment"],autopct ="%1.1f%%", colors=color)
plt.title("Alignments of DC characters")
plt.legend()
data
# Out:
# shape: (4, 2)
# ┌───────────┬─────┐
# │ Alignment ┆ len │
# │ ---       ┆ --- │
# │ str       ┆ u32 │
# ╞═══════════╪═════╡
# │ -         ┆ 1   │
# │ bad       ┆ 37  │
# │ good      ┆ 85  │
# │ neutral   ┆ 8   │
# └───────────┴─────┘

# %%
data = df.group_by("Species").len() #
data
# Out:
# shape: (24, 2)
# ┌────────────┬─────┐
# │ Species    ┆ len │
# │ ---        ┆ --- │
# │ str        ┆ u32 │
# ╞════════════╪═════╡
# │ Android    ┆ 2   │
# │ Zombie     ┆ 1   │
# │ Metahuman  ┆ 2   │
# │ Mutant     ┆ 1   │
# │ Alien      ┆ 1   │
# │ …          ┆ …   │
# │ Korugaran  ┆ 1   │
# │ Kryptonian ┆ 5   │
# │ Bizarro    ┆ 1   │
# │ Amazon     ┆ 2   │
# │ Gorilla    ┆ 1   │
# └────────────┴─────┘
