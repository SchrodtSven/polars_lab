# %% [markdown]
# # Marvel character statz

# %%
# 3rd party imports
import polars as pl
import datetime as dt

# %%
df = pl.read_csv("../dta/marvel_sanitized_w_h.csv")

# %%
species = df.group_by("Species").len()
print(species)
type(species)
# Out:
# shape: (31, 2)
# ┌───────────────────┬─────┐
# │ Species           ┆ len │
# │ ---               ┆ --- │
# │ str               ┆ u32 │
# ╞═══════════════════╪═════╡
# │ Mutant / Clone    ┆ 1   │
# │ Mutant            ┆ 47  │
# │ Atlantean         ┆ 1   │
# │ Zen-Whoberian     ┆ 1   │
# │ -                 ┆ 109 │
# │ …                 ┆ …   │
# │ Animal            ┆ 1   │
# │ Human / Radiation ┆ 9   │
# │ Android           ┆ 2   │
# │ God / Eternal     ┆ 1   │
# │ Vampire           ┆ 2   │
# └───────────────────┴─────┘
# polars.dataframe.frame.DataFrame

# %%
species = species.sort(by="len", descending=True)
species
# Out:
# shape: (31, 2)
# ┌───────────────────┬─────┐
# │ Species           ┆ len │
# │ ---               ┆ --- │
# │ str               ┆ u32 │
# ╞═══════════════════╪═════╡
# │ -                 ┆ 112 │
# │ Human             ┆ 76  │
# │ Mutant            ┆ 47  │
# │ Human / Radiation ┆ 9   │
# │ Symbiote          ┆ 7   │
# │ …                 ┆ …   │
# │ God / Eternal     ┆ 1   │
# │ Animal            ┆ 1   │
# │ Zen-Whoberian     ┆ 1   │
# │ Mutant / Clone    ┆ 1   │
# │ Flora Colossus    ┆ 1   │
# └───────────────────┴─────┘

# %%
nan = df.filter(pl.col("Species") == "-")

nan
# Out:
# shape: (112, 11)
# ┌─────┬────────────────┬───────────┬────────┬───┬───────────────┬───────────┬────────┬────────┐
# │ ID  ┆ Name           ┆ Alignment ┆ Gender ┆ … ┆ Publisher     ┆ SkinColor ┆ Height ┆ Weight │
# │ --- ┆ ---            ┆ ---       ┆ ---    ┆   ┆ ---           ┆ ---       ┆ ---    ┆ ---    │
# │ i64 ┆ str            ┆ str       ┆ str    ┆   ┆ str           ┆ str       ┆ i64    ┆ i64    │
# ╞═════╪════════════════╪═══════════╪════════╪═══╪═══════════════╪═══════════╪════════╪════════╡
# │ 40  ┆ Arclight       ┆ bad       ┆ Female ┆ … ┆ Marvel Comics ┆ -         ┆ 173    ┆ 57     │
# │ 43  ┆ Ariel          ┆ good      ┆ Female ┆ … ┆ Marvel Comics ┆ -         ┆ 165    ┆ 59     │
# │ 44  ┆ Armor          ┆ good      ┆ Female ┆ … ┆ Marvel Comics ┆ -         ┆ 163    ┆ 50     │
# │ 61  ┆ Bantam         ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 165    ┆ 54     │
# │ 71  ┆ Battlestar     ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 198    ┆ 133    │
# ...

# %%
eter = df.filter(pl.col("Species") == "Eternal")

eter
# Out:
# shape: (2, 11)
# ┌─────┬──────────┬───────────┬────────┬───┬───────────────┬───────────┬────────┬────────┐
# │ ID  ┆ Name     ┆ Alignment ┆ Gender ┆ … ┆ Publisher     ┆ SkinColor ┆ Height ┆ Weight │
# │ --- ┆ ---      ┆ ---       ┆ ---    ┆   ┆ ---           ┆ ---       ┆ ---    ┆ ---    │
# │ i64 ┆ str      ┆ str       ┆ str    ┆   ┆ str           ┆ str       ┆ i64    ┆ i64    │
# ╞═════╪══════════╪═══════════╪════════╪═══╪═══════════════╪═══════════╪════════╪════════╡
# │ 337 ┆ Hyperion ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 183    ┆ 207    │
# │ 657 ┆ Thanos   ┆ bad       ┆ Male   ┆ … ┆ Marvel Comics ┆ purple    ┆ 201    ┆ 443    │
# └─────┴──────────┴───────────┴────────┴───┴───────────────┴───────────┴────────┴────────┘

# %%
w_max = df.filter(pl.col("Weight") > 300)

w_max
# Out:
# shape: (19, 11)
# ┌─────┬────────────────────┬───────────┬────────┬───┬───────────────┬───────────┬────────┬────────┐
# │ ID  ┆ Name               ┆ Alignment ┆ Gender ┆ … ┆ Publisher     ┆ SkinColor ┆ Height ┆ Weight │
# │ --- ┆ ---                ┆ ---       ┆ ---    ┆   ┆ ---           ┆ ---       ┆ ---    ┆ ---    │
# │ i64 ┆ str                ┆ str       ┆ str    ┆   ┆ str           ┆ str       ┆ i64    ┆ i64    │
# ╞═════╪════════════════════╪═══════════╪════════╪═══╪═══════════════╪═══════════╪════════╪════════╡
# │ 33  ┆ Anti-Venom         ┆ -         ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 229    ┆ 358    │
# │ 119 ┆ Bloodaxe           ┆ bad       ┆ Female ┆ … ┆ Marvel Comics ┆ -         ┆ 218    ┆ 495    │
# │ 217 ┆ Destroyer          ┆ bad       ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 188    ┆ 383    │
# │ 233 ┆ Drax the Destroyer ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ green     ┆ 193    ┆ 306    │
# ...

# %%
h_max = df.filter(pl.col("Height") > 200)

h_max
# Out:
# shape: (34, 11)
# ┌─────┬───────────────┬───────────┬────────┬───┬───────────────┬───────────┬────────┬────────┐
# │ ID  ┆ Name          ┆ Alignment ┆ Gender ┆ … ┆ Publisher     ┆ SkinColor ┆ Height ┆ Weight │
# │ --- ┆ ---           ┆ ---       ┆ ---    ┆   ┆ ---           ┆ ---       ┆ ---    ┆ ---    │
# │ i64 ┆ str           ┆ str       ┆ str    ┆   ┆ str           ┆ str       ┆ i64    ┆ i64    │
# ╞═════╪═══════════════╪═══════════╪════════╪═══╪═══════════════╪═══════════╪════════╪════════╡
# │ 29  ┆ Ant-Man       ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 211    ┆ 122    │
# │ 33  ┆ Anti-Venom    ┆ -         ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 229    ┆ 358    │
# │ 34  ┆ Apocalypse    ┆ bad       ┆ Male   ┆ … ┆ Marvel Comics ┆ grey      ┆ 213    ┆ 135    │
# │ 78  ┆ Beta Ray Bill ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 201    ┆ 216    │
# │ 119 ┆ Bloodaxe      ┆ bad       ┆ Female ┆ … ┆ Marvel Comics ┆ -         ┆ 218    ┆ 495    │
# ...

# %% [markdown]
# ### String operations

# %%
ind = df.filter(pl.col("Name").str.starts_with("Tha"))

ind
# Out:
# shape: (1, 11)
# ┌─────┬────────┬───────────┬────────┬───┬───────────────┬───────────┬────────┬────────┐
# │ ID  ┆ Name   ┆ Alignment ┆ Gender ┆ … ┆ Publisher     ┆ SkinColor ┆ Height ┆ Weight │
# │ --- ┆ ---    ┆ ---       ┆ ---    ┆   ┆ ---           ┆ ---       ┆ ---    ┆ ---    │
# │ i64 ┆ str    ┆ str       ┆ str    ┆   ┆ str           ┆ str       ┆ i64    ┆ i64    │
# ╞═════╪════════╪═══════════╪════════╪═══╪═══════════════╪═══════════╪════════╪════════╡
# │ 657 ┆ Thanos ┆ bad       ┆ Male   ┆ … ┆ Marvel Comics ┆ purple    ┆ 201    ┆ 443    │
# └─────┴────────┴───────────┴────────┴───┴───────────────┴───────────┴────────┴────────┘

# %% [markdown]
# ### Operations on other data types

# %%
ind = df.filter(pl.col("Weight").is_between(500, 1000))

ind
# Out:
# shape: (4, 11)
# ┌─────┬────────────┬───────────┬────────┬───┬───────────────┬───────────┬────────┬────────┐
# │ ID  ┆ Name       ┆ Alignment ┆ Gender ┆ … ┆ Publisher     ┆ SkinColor ┆ Height ┆ Weight │
# │ --- ┆ ---        ┆ ---       ┆ ---    ┆   ┆ ---           ┆ ---       ┆ ---    ┆ ---    │
# │ i64 ┆ str        ┆ str       ┆ str    ┆   ┆ str           ┆ str       ┆ i64    ┆ i64    │
# ╞═════╪════════════╪═══════════╪════════╪═══╪═══════════════╪═══════════╪════════╪════════╡
# │ 331 ┆ Hulk       ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ green     ┆ 244    ┆ 630    │
# │ 373 ┆ Juggernaut ┆ neutral   ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 287    ┆ 855    │
# │ 549 ┆ Red Hulk   ┆ neutral   ┆ Male   ┆ … ┆ Marvel Comics ┆ red       ┆ 213    ┆ 630    │
# │ 575 ┆ Sasquatch  ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 305    ┆ 900    │
# └─────┴────────────┴───────────┴────────┴───┴───────────────┴───────────┴────────┴────────┘

# %%
mx = df.select(pl.max("Weight"))
mx
# Out:
# shape: (1, 1)
# ┌────────┐
# │ Weight │
# │ ---    │
# │ i64    │
# ╞════════╡
# │ 900    │
# └────────┘

# %%
df.select(pl.max("Height"))
# Out:
# shape: (1, 1)
# ┌────────┐
# │ Height │
# │ ---    │
# │ i64    │
# ╞════════╡
# │ 975    │
# └────────┘

# %%
df.filter(pl.col("Height")>900)
# Out:
# shape: (1, 1)
# ┌────────┐
# │ Height │
# │ ---    │
# │ bool   │
# ╞════════╡
# │ true   │
# └────────┘
