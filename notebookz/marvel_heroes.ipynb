# %% [markdown]
# # Marvel character statz

# %%
# 3rd party imports
import polars as pl
import datetime as dt

# %%
df = pl.read_csv("../dta/marvel_sanitized_w_h.csv")
# df = pl.read_csv("../dta/df.csv")
#df = df.filter(pl.col("Height") != -99).filter(pl.col("Weight") != -99)
#df.write_csv("marvel_sanitized_w_h.csv")

# %%
result = df.select(
    pl.col(["Name", "Weight"]),
    (pl.col("Weight") / (pl.col("Height")/100) ** 2).alias("BMI"),
)
result
# Out:
# shape: (298, 3)
# ┌─────────────────┬────────┬───────────┐
# │ Name            ┆ Weight ┆ BMI       │
# │ ---             ┆ ---    ┆ ---       │
# │ str             ┆ i64    ┆ f64       │
# ╞═════════════════╪════════╪═══════════╡
# │ Ant-Man         ┆ 122    ┆ 27.402799 │
# │ Ant-Man II      ┆ 86     ┆ 25.680074 │
# │ Anti-Venom      ┆ 358    ┆ 68.267196 │
# │ Apocalypse      ┆ 135    ┆ 29.756001 │
# │ Arachne         ┆ 63     ┆ 20.571429 │
# │ …               ┆ …      ┆ …         │
# │ X-23            ┆ 50     ┆ 20.811655 │
# │ X-Man           ┆ 61     ┆ 19.918367 │
# │ Yellow Claw     ┆ 95     ┆ 26.878678 │
# │ Yellowjacket    ┆ 83     ┆ 24.784258 │
# │ Yellowjacket II ┆ 52     ┆ 19.100092 │
# └─────────────────┴────────┴───────────┘

# %%
df.filter(pl.col("Weight") == df["Weight"].max())
# Out:
# shape: (1, 11)
# ┌─────┬───────────┬───────────┬────────┬───┬───────────────┬───────────┬────────┬────────┐
# │ ID  ┆ Name      ┆ Alignment ┆ Gender ┆ … ┆ Publisher     ┆ SkinColor ┆ Height ┆ Weight │
# │ --- ┆ ---       ┆ ---       ┆ ---    ┆   ┆ ---           ┆ ---       ┆ ---    ┆ ---    │
# │ i64 ┆ str       ┆ str       ┆ str    ┆   ┆ str           ┆ str       ┆ i64    ┆ i64    │
# ╞═════╪═══════════╪═══════════╪════════╪═══╪═══════════════╪═══════════╪════════╪════════╡
# │ 575 ┆ Sasquatch ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 305    ┆ 900    │
# └─────┴───────────┴───────────┴────────┴───┴───────────────┴───────────┴────────┴────────┘

# %%
df.filter(pl.col("Weight") == df["Weight"].min())
# Out:
# shape: (1, 11)
# ┌─────┬───────┬───────────┬────────┬───┬───────────────┬───────────┬────────┬────────┐
# │ ID  ┆ Name  ┆ Alignment ┆ Gender ┆ … ┆ Publisher     ┆ SkinColor ┆ Height ┆ Weight │
# │ --- ┆ ---   ┆ ---       ┆ ---    ┆   ┆ ---           ┆ ---       ┆ ---    ┆ ---    │
# │ i64 ┆ str   ┆ str       ┆ str    ┆   ┆ str           ┆ str       ┆ i64    ┆ i64    │
# ╞═════╪═══════╪═══════════╪════════╪═══╪═══════════════╪═══════════╪════════╪════════╡
# │ 302 ┆ Groot ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 701    ┆ 4      │
# └─────┴───────┴───────────┴────────┴───┴───────────────┴───────────┴────────┴────────┘

# %%
df.filter(pl.col("Height") == df["Height"].max())
# Out:
# shape: (1, 11)
# ┌─────┬───────────────┬───────────┬────────┬───┬───────────────┬───────────┬────────┬────────┐
# │ ID  ┆ Name          ┆ Alignment ┆ Gender ┆ … ┆ Publisher     ┆ SkinColor ┆ Height ┆ Weight │
# │ --- ┆ ---           ┆ ---       ┆ ---    ┆   ┆ ---           ┆ ---       ┆ ---    ┆ ---    │
# │ i64 ┆ str           ┆ str       ┆ str    ┆   ┆ str           ┆ str       ┆ i64    ┆ i64    │
# ╞═════╪═══════════════╪═══════════╪════════╪═══╪═══════════════╪═══════════╪════════╪════════╡
# │ 255 ┆ Fin Fang Foom ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ green     ┆ 975    ┆ 18     │
# └─────┴───────────────┴───────────┴────────┴───┴───────────────┴───────────┴────────┴────────┘

# %%
df.filter(pl.col("Height") == df["Height"].min())
# Out:
# shape: (1, 11)
# ┌─────┬─────────────────┬───────────┬────────┬───┬───────────────┬───────────┬────────┬────────┐
# │ ID  ┆ Name            ┆ Alignment ┆ Gender ┆ … ┆ Publisher     ┆ SkinColor ┆ Height ┆ Weight │
# │ --- ┆ ---             ┆ ---       ┆ ---    ┆   ┆ ---           ┆ ---       ┆ ---    ┆ ---    │
# │ i64 ┆ str             ┆ str       ┆ str    ┆   ┆ str           ┆ str       ┆ i64    ┆ i64    │
# ╞═════╪═════════════════╪═══════════╪════════╪═══╪═══════════════╪═══════════╪════════╪════════╡
# │ 330 ┆ Howard the Duck ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 79     ┆ 18     │
# └─────┴─────────────────┴───────────┴────────┴───┴───────────────┴───────────┴────────┴────────┘

# %%
import matplotlib.pyplot as plt

# %%
labels = df.group_by("Alignment").len() # #value_counts()
# sizes = df.alignment.value_counts().values
# color = ["green","red","blue"]
# explode =[0,0,0]
plt.subplots(figsize =(10,10))
plt.pie(labels["len"],labels=labels["Alignment"],autopct ="%1.1f%%")
plt.title("Percentages of Characters Alignment's")
plt.legend()
labels
# Out:
# shape: (4, 2)
# ┌───────────┬─────┐
# │ Alignment ┆ len │
# │ ---       ┆ --- │
# │ str       ┆ u32 │
# ╞═══════════╪═════╡
# │ -         ┆ 2   │
# │ good      ┆ 204 │
# │ neutral   ┆ 9   │
# │ bad       ┆ 83  │
# └───────────┴─────┘
