# %% [markdown]
# # Marvel character statz

# %%
# 3rd party imports
import polars as pl
import datetime as dt

# %%
df = pl.read_csv("../dta/marvel.csv")
df
# Out:
# shape: (360, 11)
# ┌─────┬─────────────────┬───────────┬────────┬───┬───────────────┬───────────┬────────┬────────┐
# │ ID  ┆ Name            ┆ Alignment ┆ Gender ┆ … ┆ Publisher     ┆ SkinColor ┆ Height ┆ Weight │
# │ --- ┆ ---             ┆ ---       ┆ ---    ┆   ┆ ---           ┆ ---       ┆ ---    ┆ ---    │
# │ i64 ┆ str             ┆ str       ┆ str    ┆   ┆ str           ┆ str       ┆ i64    ┆ i64    │
# ╞═════╪═════════════════╪═══════════╪════════╪═══╪═══════════════╪═══════════╪════════╪════════╡
# │ 29  ┆ Ant-Man         ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 211    ┆ 122    │
# │ 30  ┆ Ant-Man II      ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 183    ┆ 86     │
# │ 33  ┆ Anti-Venom      ┆ -         ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 229    ┆ 358    │
# │ 34  ┆ Apocalypse      ┆ bad       ┆ Male   ┆ … ┆ Marvel Comics ┆ grey      ┆ 213    ┆ 135    │
# │ 38  ┆ Arachne         ┆ good      ┆ Female ┆ … ┆ Marvel Comics ┆ -         ┆ 175    ┆ 63     │
# │ …   ┆ …               ┆ …         ┆ …      ┆ … ┆ …             ┆ …         ┆ …      ┆ …      │
# │ 725 ┆ X-23            ┆ good      ┆ Female ┆ … ┆ Marvel Comics ┆ -         ┆ 155    ┆ 50     │
# │ 726 ┆ X-Man           ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 175    ┆ 61     │
# │ 727 ┆ Yellow Claw     ┆ bad       ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 188    ┆ 95     │
# │ 728 ┆ Yellowjacket    ┆ good      ┆ Male   ┆ … ┆ Marvel Comics ┆ -         ┆ 183    ┆ 83     │
# │ 729 ┆ Yellowjacket II ┆ good      ┆ Female ┆ … ┆ Marvel Comics ┆ -         ┆ 165    ┆ 52     │
# └─────┴─────────────────┴───────────┴────────┴───┴───────────────┴───────────┴────────┴────────┘

# %%
result = df.select(
    pl.col(["Name", "Weight"]),
    (pl.col("Weight") / (pl.col("Height")/100) ** 2).alias("BMI"),
)
result
# Out:
# shape: (360, 3)
# ┌─────────────────┬────────┬───────────┐
# │ Name            ┆ Weight ┆ BMI       │
# │ ---             ┆ ---    ┆ ---       │
# │ str             ┆ i64    ┆ f64       │
# ╞═════════════════╪════════╪═══════════╡
# │ Ant-Man         ┆ 122    ┆ 27.402799 │
# │ Ant-Man II      ┆ 86     ┆ 25.680074 │
# │ Anti-Venom      ┆ 358    ┆ 68.267196 │
# │ Apocalypse      ┆ 135    ┆ 29.756001 │
# │ Arachne         ┆ 63     ┆ 20.571429 │
# │ …               ┆ …      ┆ …         │
# │ X-23            ┆ 50     ┆ 20.811655 │
# │ X-Man           ┆ 61     ┆ 19.918367 │
# │ Yellow Claw     ┆ 95     ┆ 26.878678 │
# │ Yellowjacket    ┆ 83     ┆ 24.784258 │
# │ Yellowjacket II ┆ 52     ┆ 19.100092 │
# └─────────────────┴────────┴───────────┘

# %%
df.filter(pl.col("Weight") == df["Weight"].max())
# Out:
# 900
